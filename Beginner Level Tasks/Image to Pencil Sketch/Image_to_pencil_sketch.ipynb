# %% [markdown]
# # LGM Task 4 - Data science Internship

# %% [markdown]
# ##Convert to Image to Pencil Sketch

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("dog.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=169x127 at 0x7F3DFD0E2D50>

# %%
grey_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=169x127 at 0x7F3DFD0635D0>

# %%
invert = cv2.bitwise_not(grey_img) 
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=169x127 at 0x7F3DFD063D10>

# %%
blur = cv2.GaussianBlur(invert, (21, 21), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=169x127 at 0x7F3DFD0E23D0>

# %%
invertedblur = cv2.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=169x127 at 0x7F3DFD06F890>

# %%
sketch = cv2.divide(grey_img, invertedblur, scale=255.0)

# %%
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=169x127 at 0x7F3DFD067ED0>
