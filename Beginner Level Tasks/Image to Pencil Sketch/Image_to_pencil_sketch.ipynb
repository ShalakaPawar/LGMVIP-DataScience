# %% [markdown]
# # LGM Task 4 - Data science Internship

# %% [markdown]
# ##Convert to Image to Pencil Sketch

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("dog.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=169x127 at 0x7F766C951C10>

# %%
grey_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
invert = cv2.bitwise_not(grey_img)  # helps in masking of the image

# %%
blur = cv2.GaussianBlur(invert, (21, 21), 0)

# %%
invertedblur = cv2.bitwise_not(blur)

# %%
sketch = cv2.divide(grey_img, invertedblur, scale=255.0)

# %%
cv2.imwrite("sketch.png", sketch)
# Out:
# True

# %%
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=169x127 at 0x7F766C931CD0>
